# %%
weight = float(input("Enter your baggage weight (in kg): "))

if weight > 15:
    print("Limit Exceeds.")
else:
    print("Your baggage is is ok.")
# Out:
# Your baggage is is ok.

# %%
total = 0

for a in range(1000):
    if a % 3 == 0 or a % 5 == 0:
        total += a

print(total)
# Out:
# 233168
